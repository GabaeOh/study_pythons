# %% [markdown]
# <a href="https://colab.research.google.com/github/GabaeOh/toy_pythons/blob/main/C_LoopWithCouter_gabae.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 5까지 1씩 증가하는 값 찍기

# %%
count = 1
print(count)
while count < 5:
  count += 1 
  print(count)
print("End")
# Out:
# 1
# 2
# 3
# 4
# 5
# End
