# %% [markdown]
# <a href="https://colab.research.google.com/github/GabaeOh/toy_pythons/blob/main/whiles_gabae.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # While문 개념 익히기

# %%
first= 1

# %%
while first < 4:
  print(first)
  print("in whiling")
  first +=1 
print("End")
# Out:
# 1
# in whiling
# 2
# in whiling
# 3
# in whiling
# End

# %% [markdown]
# # 두 번째 입력을 합니다.
